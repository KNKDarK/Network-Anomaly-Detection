# %% [markdown]
# # 02 - Preprocessing & Feature Engineering

# %% [markdown]
# ## Handle missing values, encode labels, scale features, balance with SMOTE

# %%
import sys
sys.path.insert(0, '..')

from src.data_utils import prepare_data, apply_smote

X_train, X_test, y_train, y_test, le, pre, feats = prepare_data()
print('Train shape:', X_train.shape)
print('Classes:', le.classes_)

# %%
X_bal, y_bal = apply_smote(X_train, y_train)
print('After SMOTE:', X_bal.shape)

# %% [markdown]
# Stratified 70/15/15 split is handled inside `prepare_data`.
